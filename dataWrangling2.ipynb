# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
df = pd.read_csv(r"C:\Users\Hp\OneDrive\Desktop\dsbdal codes\StudentsPerformanceTest1.csv")

# %%
df.describe()
# Out:
#        writing score  Placement Score  placement offer count
# count       8.000000         8.000000               9.000000
# mean       77.000000        62.125000               1.777778
# std        13.416408        23.295846               1.201850
# min        52.000000        12.000000               0.000000
# 25%        72.250000        53.500000               1.000000
# 50%        76.500000        72.000000               2.000000
# 75%        88.250000        78.000000               2.000000
# max        93.000000        81.000000               4.000000

# %%
df.head()
# Out:
#    gender math score reading score  writing score  Placement Score  \
# 0  female         72            72           74.0             78.0
# 1  female         69            90           88.0              NaN
# 2  female         90            95           93.0             74.0
# 3    male         47            57            NaN             78.0
# 4    male         na            78           75.0             81.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune

# %%
df.columns
# Out:
# Index(['gender', 'math score', 'reading score', 'writing score',
#        'Placement Score', 'placement offer count', 'Region'],
#       dtype='object')

# %%
df.shape
# Out:
# (9, 7)

# %%
df.dtypes
# Out:
# gender                    object
# math score                object
# reading score             object
# writing score            float64
# Placement Score          float64
# placement offer count      int64
# Region                    object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
df.columns.values
# Out:
# array(['gender', 'math score', 'reading score', 'writing score',
#        'Placement Score', 'placement offer count', 'Region'], dtype=object)

# %%
df.iloc[4]
# Out:
# gender                   male
# math score                 na
# reading score              78
# writing score            75.0
# Placement Score          81.0
# placement offer count       3
# Region                   Pune
# Name: 4, dtype: object

# %%
df.isnull()
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0   False       False          False          False            False
# 1   False       False          False          False             True
# 2   False       False          False          False            False
# 3   False       False          False           True            False
# 4   False       False          False          False            False
# 5   False       False          False          False            False
# 6   False       False          False          False            False
# 7   False        True          False          False            False
# 8   False       False          False          False            False
#
#    placement offer count  Region
# 0                  False   False
# 1                  False   False
# 2                  False   False
# 3                  False   False
# 4                  False   False
# 5                  False   False
# 6                  False   False
# ...

# %%
df.isnull().any()
# Out:
# gender                   False
# math score                True
# reading score            False
# writing score             True
# Placement Score           True
# placement offer count    False
# Region                    True
# dtype: bool

# %%
df.isnull().sum(axis=1)
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# 5    0
# 6    0
# 7    1
# 8    1
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['gender'] = le.fit_transform(df['gender'])
newdf = df

# %%
df
# Out:
#    gender math score reading score  writing score  Placement Score  \
# 0       0         72            72           74.0             78.0
# 1       0         69            90           88.0              NaN
# 2       0         90            95           93.0             74.0
# 3       1         47            57            NaN             78.0
# 4       1         na            78           75.0             81.0
# 5       0         71            Na           78.0             70.0
# 6       1         12            44           52.0             12.0
# 7       1        NaN            65           67.0             49.0
# 8       1          5            77           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune
# 5                      4      na
# 6                      2  Nashik
# ...

# %%
newdf.describe()
# Out:
#          gender  writing score  Placement Score  placement offer count
# count  9.000000       8.000000         8.000000               9.000000
# mean   0.555556      77.000000        62.125000               1.777778
# std    0.527046      13.416408        23.295846               1.201850
# min    0.000000      52.000000        12.000000               0.000000
# 25%    0.000000      72.250000        53.500000               1.000000
# 50%    1.000000      76.500000        72.000000               2.000000
# 75%    1.000000      88.250000        78.000000               2.000000
# max    1.000000      93.000000        81.000000               4.000000

# %%
missing_values = ['na','Na']
df = pd.read_csv(r"C:\Users\Hp\OneDrive\Desktop\dsbdal codes\StudentsPerformanceTest1.csv",na_values = missing_values)
df
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female        72.0           72.0           74.0             78.0
# 1  female        69.0           90.0           88.0              NaN
# 2  female        90.0           95.0           93.0             74.0
# 3    male        47.0           57.0            NaN             78.0
# 4    male         NaN           78.0           75.0             81.0
# 5  female        71.0            NaN           78.0             70.0
# 6    male        12.0           44.0           52.0             12.0
# 7    male         NaN           65.0           67.0             49.0
# 8    male         5.0           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
ndf=df
ndf.fillna(0)
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           72.0           74.0             78.0
# 1  female   69.000000           90.0           88.0              0.0
# 2  female   90.000000           95.0           93.0             74.0
# 3    male   47.000000           57.0            0.0             78.0
# 4    male   52.285714           78.0           75.0             81.0
# 5  female   71.000000            0.0           78.0             70.0
# 6    male   12.000000           44.0           52.0             12.0
# 7    male   52.285714           65.0           67.0             49.0
# 8    male    5.000000           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2       0
# 2                      2  Nashik
# 3                      1       0
# 4                      3    Pune
# 5                      4       0
# 6                      2  Nashik
# ...

# %%
data = df
data['math score'] = data['math score'].fillna(data['math score'].mean())

# %%
data
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           72.0           74.0             78.0
# 1  female   69.000000           90.0           88.0              NaN
# 2  female   90.000000           95.0           93.0             74.0
# 3    male   47.000000           57.0            NaN             78.0
# 4    male   52.285714           78.0           75.0             81.0
# 5  female   71.000000            NaN           78.0             70.0
# 6    male   12.000000           44.0           52.0             12.0
# 7    male   52.285714           65.0           67.0             49.0
# 8    male    5.000000           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
data = df
data['math score'] = data['math score'].fillna(data['math score'].median())
data
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           72.0           74.0             78.0
# 1  female   69.000000           90.0           88.0              NaN
# 2  female   90.000000           95.0           93.0             74.0
# 3    male   47.000000           57.0            NaN             78.0
# 4    male   52.285714           78.0           75.0             81.0
# 5  female   71.000000            NaN           78.0             70.0
# 6    male   12.000000           44.0           52.0             12.0
# 7    male   52.285714           65.0           67.0             49.0
# 8    male    5.000000           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
data = df
data['math score'] = data['math score'].fillna(data['math score'].min())

# %%
data
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           72.0           74.0             78.0
# 1  female   69.000000           90.0           88.0              NaN
# 2  female   90.000000           95.0           93.0             74.0
# 3    male   47.000000           57.0            NaN             78.0
# 4    male   52.285714           78.0           75.0             81.0
# 5  female   71.000000            NaN           78.0             70.0
# 6    male   12.000000           44.0           52.0             12.0
# 7    male   52.285714           65.0           67.0             49.0
# 8    male    5.000000           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
data = df
data['math score'] = data['math score'].fillna(data['math score'].max())
data
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           72.0           74.0             78.0
# 1  female   69.000000           90.0           88.0              NaN
# 2  female   90.000000           95.0           93.0             74.0
# 3    male   47.000000           57.0            NaN             78.0
# 4    male   52.285714           78.0           75.0             81.0
# 5  female   71.000000            NaN           78.0             70.0
# 6    male   12.000000           44.0           52.0             12.0
# 7    male   52.285714           65.0           67.0             49.0
# 8    male    5.000000           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
ndf = df
ndf.dropna()
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           72.0           74.0             78.0
# 2  female   90.000000           95.0           93.0             74.0
# 4    male   52.285714           78.0           75.0             81.0
# 6    male   12.000000           44.0           52.0             12.0
# 7    male   52.285714           65.0           67.0             49.0
#
#    placement offer count  Region
# 0                      1    Pune
# 2                      2  Nashik
# 4                      3    Pune
# 6                      2  Nashik
# 7                      1    Pune

# %%
ndf = df
ndf.dropna(axis = 1)
# Out:
#    gender  math score  placement offer count
# 0  female   72.000000                      1
# 1  female   69.000000                      2
# 2  female   90.000000                      2
# 3    male   47.000000                      1
# 4    male   52.285714                      3
# 5  female   71.000000                      4
# 6    male   12.000000                      2
# 7    male   52.285714                      1
# 8    male    5.000000                      0

# %%
newdf1 = pd.read_csv(r"C:\Users\Hp\OneDrive\Desktop\dsbdal codes\demo.csv")

# %%
newdf1
# Out:
#     math score  reading score  writing score  placement score  \
# 0           80             68             70               89
# 1           71             61             85               91
# 2           79             16             87               77
# 3           61             77             74               76
# 4           78             71             67               90
# 5           73             68             90               80
# 6           77             62             70               35
# 7           74             45             80               12
# 8           76             60             79               77
# 9           75             65             85               87
# 10         160             67             12               83
# 11          79             72             88              180
# 12          80             80             78               94
# 13          78             69             71               90
# ...

# %%
min_max_scaler = preprocessing.MinMaxScaler()

# %%
x = newdf1.iloc[:,:6]

# %%
x_scaled = min_max_scaler.fit_transform(x)

# %%
df_normalized = pd.DataFrame(x_scaled)

# %%
df_normalized
# Out:
#            0         1         2         3    4         5
# 0   0.159664  0.563025  0.743590  0.458333  1.0  0.333333
# 1   0.084034  0.504202  0.935897  0.470238  1.0  0.333333
# 2   0.151261  0.126050  0.961538  0.386905  0.5  0.000000
# 3   0.000000  0.638655  0.794872  0.380952  0.5  0.666667
# 4   0.142857  0.588235  0.705128  0.464286  1.0  0.333333
# 5   0.100840  0.563025  1.000000  0.404762  0.5  0.333333
# 6   0.134454  0.512605  0.743590  0.136905  0.5  0.666667
# 7   0.109244  0.369748  0.871795  0.000000  0.0  0.333333
# 8   0.126050  0.495798  0.858974  0.386905  0.5  0.666667
# 9   0.117647  0.537815  0.935897  0.446429  1.0  0.000000
# 10  0.831933  0.554622  0.000000  0.422619  0.5  0.666667
# 11  0.151261  0.596639  0.974359  1.000000  0.5  0.333333
# 12  0.159664  0.663866  0.846154  0.488095  1.0  1.000000
# 13  0.142857  0.571429  0.756410  0.464286  1.0  0.333333
# 14  0.117647  0.000000  0.756410  0.410714  0.5  0.333333
# ...

# %%
newdf1['placement score'].unique()
# Out:
# array([ 89,  91,  77,  76,  90,  80,  35,  12,  87,  83, 180,  94,  81,
#         93,  88,  84,  75,  85], dtype=int64)

# %%
newdf1.describe()
# Out:
#        math score  reading score  writing score  placement score  \
# count   29.000000      29.000000      29.000000        29.000000
# mean    84.482759      65.896552      73.793103        82.724138
# std     25.973366      20.098587      17.341897        26.891178
# min     61.000000       1.000000      12.000000        12.000000
# 25%     74.000000      62.000000      70.000000        77.000000
# 50%     77.000000      68.000000      78.000000        85.000000
# 75%     80.000000      74.000000      85.000000        91.000000
# max    180.000000     120.000000      90.000000       180.000000
#
#        placement offer count  club join year
# count              29.000000       29.000000
# mean                2.448276     2019.448276
# std                 0.631676        0.985111
# min                 1.000000     2018.000000
# 25%                 2.000000     2019.000000
# 50%                 3.000000     2019.000000
# 75%                 3.000000     2020.000000
# ...

# %%
pd.set_option('display.max_columns',4)

# %%
data_score=newdf1.drop(columns='club join year')

# %%
print(data_score)
# Out:
#     math score  reading score  ...  placement score  placement offer count
# 0           80             68  ...               89                      3
# 1           71             61  ...               91                      3
# 2           79             16  ...               77                      2
# 3           61             77  ...               76                      2
# 4           78             71  ...               90                      3
# 5           73             68  ...               80                      2
# 6           77             62  ...               35                      2
# 7           74             45  ...               12                      1
# 8           76             60  ...               77                      2
# 9           75             65  ...               87                      3
# 10         160             67  ...               83                      2
# ...

# %%
col = ['math score','reading score','writing score','placement score','placement offer count']

# %%
print("outliers using box plot")
# Out:
# outliers using box plot

# %%
print(np.where(newdf1['math score']>95))
print(np.where(df['reading score']<25))
print(np.where(df['writing score']<30))
# Out:
# (array([10, 21, 25, 28], dtype=int64),)
# (array([ 2, 14], dtype=int64),)
# (array([10, 17], dtype=int64),)

# %%
box_plot = data_score.boxplot(col)

# %%
mask=newdf1['math score']>95

# %%
refined_df = newdf1[~mask]

# %%
print(refined_df)
# Out:
#     math score  reading score  ...  placement offer count  club join year
# 0           80             68  ...                      3            2019
# 1           71             61  ...                      3            2019
# 2           79             16  ...                      2            2018
# 3           61             77  ...                      2            2020
# 4           78             71  ...                      3            2019
# 5           73             68  ...                      2            2019
# 6           77             62  ...                      2            2020
# 7           74             45  ...                      1            2019
# 8           76             60  ...                      2            2020
# 9           75             65  ...                      3            2018
# 11          79             72  ...                      2            2019
# 12          80             80  ...                      3            2021
# ...

# %%
col = ['math score','reading score','writing score','placement score','placement offer count']

# %%
box_plot =data_score.boxplot(col)

# %%
plt.show(box_plot)

# %%
col=['math score']

# %%
box_plot1 = refined_df.boxplot(col)

# %%
plt.show(box_plot1)

# %%
col = ['reading score']

# %%
box_plot3=df.boxplot(col)

# %%
plt.show(box_plot3)

# %%
fig,sca_plt = plt.subplots(figsize = (18,10))
sca_plt.scatter(newdf1['placement score'],newdf1['placement offer count'])
sca_plt.set_xlabel('(Proportion non-retail business acres)/(town)')
sca_plt.set_ylabel('(Full-value property-tax rate)/($10,000)')
# Out:
# Text(0, 0.5, '(Full-value property-tax rate)/($10,000)')

# %%
plt.show(sca_plt)

# %%
print(np.where((df['placement score']<50) & (df['placement offer count']>1)))
print(np.where((df['placement score']>85) & (df['placement offer count']<3)))
# Out:
# (array([6], dtype=int64),)
# (array([11], dtype=int64),)

# %%
from scipy import stats
z = np.abs(stats.zscore(newdf1['math score']))
z
# Out:
# 0     0.175646
# 1     0.528288
# 2     0.214828
# 3     0.920112
# 4     0.254010
# 5     0.449923
# 6     0.293193
# 7     0.410740
# 8     0.332375
# 9     0.371558
# 10    2.958952
# 11    0.214828
# 12    0.175646
# 13    0.254010
# 14    0.371558
# 15    0.254010
# 16    0.059449
# 17    0.175646
# 18    0.371558
# 19    0.097281
# 20    0.606653
# 21    0.608004
# 22    0.489105
# 23    0.410740
# 24    0.371558
# 25    3.742601
# 26    0.489105
# 27    0.528288
# 28    1.391653
# Name: math score, dtype: float64

# %%
threshould = 0.18
sample_outliers = np.where(z < threshould)
sample_outliers
# Out:
# (array([ 0, 12, 16, 17, 19], dtype=int64),)
