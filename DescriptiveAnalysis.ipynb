# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Hp\OneDrive\Desktop\dsbdal codes\Mall_Customers.csv")
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.loc[:,'Age'].mean()
# Out:
# 38.85

# %%
df.loc[:,"Spending Score (1-100)"].mean()
# Out:
# 50.2

# %%
df.loc[:,"Age"].median()
# Out:
# 36.0

# %%
df.groupby(['Genre'])['Age'].mean()
# Out:
# Genre
# Female    38.098214
# Male      39.806818
# Name: Age, dtype: float64

# %%
newdf = df.rename(columns = {'Annual Income (k$)':'income'},inplace = False)

# %%
newdf
# Out:
#      CustomerID   Genre  Age  income  Spending Score (1-100)
# 0             1    Male   19      15                      39
# 1             2    Male   21      15                      81
# 2             3  Female   20      16                       6
# 3             4  Female   23      16                      77
# 4             5  Female   31      17                      40
# ..          ...     ...  ...     ...                     ...
# 195         196  Female   35     120                      79
# 196         197  Female   45     126                      28
# 197         198    Male   32     126                      74
# 198         199    Male   32     137                      18
# 199         200    Male   30     137                      83
#
# [200 rows x 5 columns]

# %%
newdf.groupby(['Genre']).income.mean()
# Out:
# Genre
# Female    59.250000
# Male      62.227273
# Name: income, dtype: float64

# %%
from sklearn import preprocessing
encoder = preprocessing.OneHotEncoder()
encoder_df = pd.DataFrame(encoder.fit_transform(newdf[['Genre']]).toarray())

# %%
encoder_df
# Out:
#        0    1
# 0    0.0  1.0
# 1    0.0  1.0
# 2    1.0  0.0
# 3    1.0  0.0
# 4    1.0  0.0
# ..   ...  ...
# 195  1.0  0.0
# 196  1.0  0.0
# 197  0.0  1.0
# 198  0.0  1.0
# 199  0.0  1.0
#
# [200 rows x 2 columns]

# %%
encoder_df = newdf.join(encoder_df)
encoder_df
# Out:
#      CustomerID   Genre  Age  income  Spending Score (1-100)    0    1
# 0             1    Male   19      15                      39  0.0  1.0
# 1             2    Male   21      15                      81  0.0  1.0
# 2             3  Female   20      16                       6  1.0  0.0
# 3             4  Female   23      16                      77  1.0  0.0
# 4             5  Female   31      17                      40  1.0  0.0
# ..          ...     ...  ...     ...                     ...  ...  ...
# 195         196  Female   35     120                      79  1.0  0.0
# 196         197  Female   45     126                      28  1.0  0.0
# 197         198    Male   32     126                      74  0.0  1.0
# 198         199    Male   32     137                      18  0.0  1.0
# 199         200    Male   30     137                      83  0.0  1.0
#
# [200 rows x 7 columns]

# %%
iris = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",names = ['Sepal_length','Sepal_Width','Petal_Length','Petal_Width','Species'])
iris
# Out:
#      Sepal_length  Sepal_Width  Petal_Length  Petal_Width         Species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
irisSet = (iris['Species'] == 'Iris-setosa')
irisSet
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: Species, Length: 150, dtype: bool

# %%
iris[irisSet].describe()
# Out:
#        Sepal_length  Sepal_Width  Petal_Length  Petal_Width
# count      50.00000    50.000000     50.000000     50.00000
# mean        5.00600     3.418000      1.464000      0.24400
# std         0.35249     0.381024      0.173511      0.10721
# min         4.30000     2.300000      1.000000      0.10000
# 25%         4.80000     3.125000      1.400000      0.20000
# 50%         5.00000     3.400000      1.500000      0.20000
# 75%         5.20000     3.675000      1.575000      0.30000
# max         5.80000     4.400000      1.900000      0.60000

# %%
irisVer = (iris['Species']=='Iris-verginica')

# %%
print('Iris-virginica')
print(iris[irisVer].describe())
# Out:
# Iris-virginica
#        Sepal_length  Sepal_Width  Petal_Length  Petal_Width
# count           0.0          0.0           0.0          0.0
# mean            NaN          NaN           NaN          NaN
# std             NaN          NaN           NaN          NaN
# min             NaN          NaN           NaN          NaN
# 25%             NaN          NaN           NaN          NaN
# 50%             NaN          NaN           NaN          NaN
# 75%             NaN          NaN           NaN          NaN
# max             NaN          NaN           NaN          NaN

# %%
irisVer = (iris['Species'] == 'Iris-Versicolor')
iris[irisVer].describe()
# Out:
#        Sepal_length  Sepal_Width  Petal_Length  Petal_Width
# count           0.0          0.0           0.0          0.0
# mean            NaN          NaN           NaN          NaN
# std             NaN          NaN           NaN          NaN
# min             NaN          NaN           NaN          NaN
# 25%             NaN          NaN           NaN          NaN
# 50%             NaN          NaN           NaN          NaN
# 75%             NaN          NaN           NaN          NaN
# max             NaN          NaN           NaN          NaN
